# %%
import io
import os

from collections import defaultdict
import tensorflow as tf
import numpy as np
from keras import backend as K
from keras.layers import Conv2D, Input, BatchNormalization, LeakyReLU, ZeroPadding2D, UpSampling2D, MaxPool2D, Activation
from keras.layers.merge import add, concatenate
from keras.models import Model
from keras.utils import get_custom_objects
from tensorflow.python.platform import build_info as tf_build_info
import tensorflow_addons as tfa

print("TensorFlow version: {}".format(tf.__version__))
print("Eager execution: {}".format(tf.executing_eagerly()))
print("Keras version: {}".format(tf.keras.__version__))

print("Num Physical GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print("Num Logical GPUs Available: ", len(tf.config.experimental.list_logical_devices('GPU')))

NETWORK_W = 608
NETWORK_H = 608

# ------------------------------------------------------------
# needs to be defined as activation class otherwise error
# AttributeError: 'Activation' object has no attribute '__name__'    



def mysoftplus(x):

    mask_min = tf.cast((x<-20.0),tf.float32)
    ymin = mask_min*tf.math.exp(x)

    mask_max = tf.cast((x>20.0),tf.float32)
    ymax = mask_max*x
    
    mask= tf.cast((abs(x)<=20.0),tf.float32)
    y = mask*tf.math.log(tf.math.exp(x) + 1.0)
    
    return(ymin+ymax+y)    
        


def _conv_block(inp, convs, skip=False):
    x = inp
    count = 0
    
    for conv in convs:
        if count == (len(convs) - 2) and skip: # handle Shorcut -3 
            skip_connection = x
        count += 1
        
        if conv['stride'] > 1: x = ZeroPadding2D(((1,0),(1,0)), name='zerop_' + str(conv['layer_idx']))(x)  # peculiar padding as darknet prefer left and top
        
        x = Conv2D(conv['filter'], 
                   conv['kernel'], 
                   strides=conv['stride'], 
                   padding='valid' if conv['stride'] > 1 else 'same', # peculiar padding as darknet prefer left and top
                   name='convn_' + str(conv['layer_idx']) if conv['bnorm'] else 'conv_' + str(conv['layer_idx']),
                   use_bias=True)(x)
        
        if conv['bnorm']: x = BatchNormalization(name='BN_' + str(conv['layer_idx']))(x)    
        
        if conv['activ'] == 1: x = LeakyReLU(alpha=0.1, name='leaky_' + str(conv['layer_idx']))(x)
        if conv['activ'] == 2: x = tfa.activations.mish(x)
            
    return add([skip_connection, x],  name='add_' + str(conv['layer_idx']+1)) if skip else x

def make_yolov4_model():
        
    input_image = Input(shape=(NETWORK_H, NETWORK_W, 3), name='input_0')

    # ---------------------------------- begin BACKBONE CSP-Darnet 53 -----------------------------------------------------------
    ## Layer 0 [convolutional]
    x = _conv_block(input_image, [{'filter': 32, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 0}])

    ## Layer 1 [convolutional]
    x = _conv_block(x, [{'filter': 64, 'kernel': 3, 'stride': 2, 'bnorm': True, 'activ': 2, 'layer_idx': 1}])
    layer_1 = x
   
    # ---------- begin 1*Conv+conv+residual 304*304    
    ## Layer 2 [convolutional] 
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 2}])
    layer_2 = x
    

    ## Layer 3 [route] layers = -2
    x = layer_1
    ## Layer  4 => 6 [convolutional] + Layer 7 [shortcut]
    x = _conv_block(x, [{'filter': 64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 4},                  
                        {'filter': 32, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 5},
                        {'filter': 64, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 6}],
                   skip = True) 
    
    ## Layer 8 [convolutional]
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 8}])
    layer_8 = x
    
    ## Layer 9 [route] layers = -1, -7
    x = concatenate([layer_8, layer_2], name='concat_9')
    
    ##  Layer 10 => 11 [convolutional]
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 10},
                        {'filter': 128, 'kernel': 3, 'stride': 2, 'bnorm': True, 'activ': 2, 'layer_idx': 11}])
    layer_11 = x
    # ---------- end 1*Conv+conv+residual 304*304
   
    # ---------- begin 2*Conv+conv+residual 152*152      
    # Layer 12 [convolutional]
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 12}])
    layer_12 = x
    
  
    ## Layer 13 [route] layers = -2
    x = layer_11
    
    ## Layer 14 => 16 [convolutional] + Layer 17 [shortcut]
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 14},                    
                        {'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 15},
                        {'filter':  64, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 16}],
                   skip = True)
    
    ## Layer 18 => 19 [convolutional] 
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 18},
                        {'filter':  64, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 19}],
                   skip = True)
    
    ## Layer 21 [convolutional] 
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 21}]) 
    layer_21 = x
    
    ## Layer 22 [route] layers = -1,-10
    x = concatenate([layer_21, layer_12], name='concat_22')
    
    ## Layer 23 => 24 [convolutional] 
    x = _conv_block(x, [{'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 23},
                        {'filter':  256, 'kernel': 3, 'stride': 2, 'bnorm': True, 'activ': 2, 'layer_idx': 24}])
    layer_24 = x
    # ---------- end 2*Conv+conv+residual 152*152        
    
    # ---------- begin 8*Conv+conv+residual 76*76    
    ## Layer  25 [convolutional] 
    x = _conv_block(x, [{'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 25}])
    layer_25 = x
        
    
    ## Layer 26 [route] layers = -2
    x = layer_24
    
    ## Layer 27 => 29 [convolutional] + Layer 30 [shortcut]
    x = _conv_block(x, [{'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 27},                       
                        {'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 28},
                        {'filter':  128, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 29}],
                   skip = True)
    
    
    ## Layer 31 => 50 [convolutional] and [shortcut] for layers 33, 36, 39, 42, 45, 48, 51
    for i in range(7):
        x = _conv_block(x, [{'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 31+(i*3)},
                            {'filter': 128, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 32+(i*3)}],
                       skip = True)
  
    ## Layer 52 [convolutional]
    x = _conv_block(x, [{'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 52}])
    layer_52 = x
        
    ## Layer 53 [route] layers = -1,-28
    x = concatenate([layer_52, layer_25],  name='concat_53')
    
 
    ## Layer 54 [convolutional]
    x = _conv_block(x, [{'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 54}])
    # ---------- initial output 76*76 
    layer_54 = x
    
    ## Layer 55 [convolutional]
    x = _conv_block(x, [{'filter':  512, 'kernel': 3, 'stride': 2, 'bnorm': True, 'activ': 2, 'layer_idx': 55}])
    layer_55 = x
    # ---------- end 8*Conv+conv+residual 76*76        
    
    # ---------- begin 8*Conv+conv+residual 38*38  
    ## Layer 56 [convolutional]
    x = _conv_block(x, [{'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 56}])
    layer_56 = x
    
    ## Layer 57 [route] layers = -2
    x = layer_55
    
    ##  Layer 58 => 60 [convolutional] + Layer 61 [shortcut]
    x = _conv_block(x, [{'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 58},
                        {'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 59},
                        {'filter':  256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 60}],
                   skip = True)     
    
    ## Layer 62 => 81 [convolutional] and [shortcut] for layers 64, 67, 70, 73, 76, 79, 82
    for i in range(7):
        x = _conv_block(x, [{'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 62+(i*3)},
                            {'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 63+(i*3)}],
                       skip = True)

    ## Layer 83 [convolutional]
    x = _conv_block(x, [{'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 83}])
    layer_83 = x

    ## Layer 84 [route] layers = -1,-28
    x = concatenate([layer_83, layer_56], name='concat_84')
    
    ## Layer 85 [convolutional]
    x = _conv_block(x, [{'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 85}])
    layer_85 = x
    # ---------- initial output 38*38 
   
    
    ## Layer 86 [convolutional]
    x = _conv_block(x, [{'filter':  1024, 'kernel': 3, 'stride': 2, 'bnorm': True, 'activ': 2, 'layer_idx': 86}])
    layer_86 = x
    
    ## Layer 87 [convolutional]
    x = _conv_block(x, [{'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 87}])
    layer_87 = x
        
    ## Layer 88 [route] layers = -2
    x = layer_86
    # ---------- end 8*Conv+conv+residual 38*38  
    
    # ---------- begin 4*Conv+conv+residual 19*19 
    ## Layer 89 => 91 [convolutional] + Layer 92 [shortcut]
    x = _conv_block(x, [{'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 89},                         
                        {'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 90},
                        {'filter':  512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 91}],
                   skip = True) 
    
    
    ## Layer 93 => 100 [convolutional] and [shortcut] for layers 95, 98, 101
    for i in range(3):
        x = _conv_block(x, [{'filter': 512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 93+(i*3)},
                            {'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 94+(i*3)}],
                       skip = True)  
    
    # ---------- end 4*Conv+conv+residual 19*19 
    
    ## Layer 102 [convolutional]
    x = _conv_block(x, [{'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 102}])  
    layer_102 = x
    
    ##  Layer 103 [route] layers = -1,-16
    x = concatenate([layer_102, layer_87], name='concat_103')
    
    ## Layer 104 => 107 [convolutional]
    x = _conv_block(x, [{'filter':  1024, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 104},
                        {'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 105},
                        {'filter':  1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 106},                        
                        {'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 107}])
    layer_107 = x 
    # ---------------------------------- end BACKBONE CSP-Darnet 53 -----------------------------------------------------------
    
    # ---------------------------------- begin SPP part (Spatial Pyramid Pooling layer) ---------------------------------------
    ## Layer 108 [maxpool]
    x =MaxPool2D(pool_size=(5, 5), strides=1, padding='same', name = 'layer_108')(x)  
    layer_108 = x
    
    ##  Layer 109 [route] layers = -2
    x = layer_107
    
    ## Layer 110 [maxpool]
    x =MaxPool2D(pool_size=(9, 9), strides=1, padding='same', name = 'layer_110')(x)    
    layer_110 = x
    
    ##  Layer 111 [route] layers = -4
    x = layer_107
        
    ## Layer 112 [maxpool]
    x =MaxPool2D(pool_size=(13, 13), strides=1, padding='same', name = 'layer_112')(x) 
    layer_112 = x
    
    ##  Layer 133 [route] layers=-1,-3,-5,-6
    x = concatenate([layer_112, layer_110, layer_108, layer_107], name='concat_113')
    # ---------------------------------- end SPP part (Spatial Pyramid Pooling layer) ---------------------------------------
 

    
    ## Layer 114 => 116 [convolutional]
    x = _conv_block(x, [{'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 114},
                        {'filter':  1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 115},
                        {'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 116}])
    layer_116 = x
                        
    ## Layer 117 [convolutional]                    
    x = _conv_block(x, [{'filter':   256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 117}])
    layer_117 = x
    
    ## Layer 118 [upsample]
    x = UpSampling2D(size=(2, 2), name = 'upsamp_118')(x)
    layer_118 = x
                        
    ##  Layer 119 [route] layers = 85
    x = layer_85
    
    ## Layer 120 [convolutional]
    x = _conv_block(x, [{'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 120}])
    layer_120 = x
                        
    ##  Layer 121 [route] layers = -1, -3
    x = concatenate([layer_120, layer_118],  name='concat_121')
    layer_121 = x    
    
  
    ## Layer 122 => 126 [convolutional]
    x = _conv_block(x, [{'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 122},
                        {'filter':  512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 123},
                        {'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 124},  
                        {'filter':  512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 125},
                        {'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 126}])
    layer_126 = x 
    
    
    ## Layer 127 [convolutional]                   
    x = _conv_block(x, [{'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 127}])
    layer_127 = x
    
    ## Layer 128 [upsample]
    x = UpSampling2D(size=(2, 2), name = 'upsamp_128')(x)
    layer_128 = x
    
    # ---------------------------------- begin head output 76*76 ---------------------------------------                   
    ## Layer 129 [route] layers = 54
    x = layer_54
    
    ## Layer 130 [convolutional]
    x = _conv_block(x, [{'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 130}])
    layer_130 = x
                        
    ## Layer 131 [route] layers = -1, -3                 
    x = concatenate([layer_130, layer_128],  name='concat_131')
    layer_131 = x
    
    # -- begin Convulationnal set 76*76
    ## Layer 132 => 136 [convolutional]
    x = _conv_block(x, [{'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':  1, 'layer_idx': 132},
                        {'filter':  256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':  1, 'layer_idx': 133},
                        {'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':  1, 'layer_idx': 134},  
                        {'filter':  256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':  1, 'layer_idx': 135},
                        {'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':  1, 'layer_idx': 136}])
    layer_136 = x                   
    
    # -- end Convulationnal set 76*76
    
    # -- beging last Convulationnal 3*3 and 1*1 for 76*76
    ## Layer 137 [convolutional]
    x = _conv_block(x, [{'filter':  256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':  1, 'layer_idx': 137}]) 
    layer_137 = x 
    
    ## Layer 138 [convolutional]
    x = _conv_block(x, [{'filter':  255, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':  0, 'layer_idx': 138}])   
    
    # -- end last Convulationnal 3*3 and 1*1 for 76*76
    
    # -- output 76*76 
    ## Layer 139 [yolo]
    yolo_139 = x
    
    # ---------------------------------- end head output 76*76 ---------------------------------------
    
    # ---------------------------------- begin head output 38*38 ---------------------------------------
    ## Layer 140 [route] layers = -4
    x = layer_136
    
    ##  Layer 141 [convolutional]
    x = _conv_block(x, [{'filter':  256, 'kernel': 3, 'stride': 2, 'bnorm': True, 'activ': 1, 'layer_idx': 141}])
    layer_141 = x
                        
    ## Layer 142 [route] layers = -1, -16                   
    x = concatenate([layer_141, layer_126],  name='concat_142')
    
    # -- begin Convulationnal set 38*38
    ## Layer 143 => 147 [convolutional]
    x = _conv_block(x, [{'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':   1, 'layer_idx': 143},
                        {'filter':  512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':   1, 'layer_idx': 144},
                        {'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':   1, 'layer_idx': 145},  
                        {'filter':  512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':   1, 'layer_idx': 146},
                        {'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':   1, 'layer_idx': 147}])  
    layer_147 = x
    
    # -- end Convulationnal set 38*38
    
    # -- beging last Convulationnal 3*3 and 1*1 for 38*38
    ## Layer 148 => 149 [convolutional]                   
    x = _conv_block(x, [{'filter':  512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':  1, 'layer_idx': 148},
                        {'filter':  255, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':  0, 'layer_idx': 149}])
    
    # -- end last Convulationnal 3*3 and 1*1 for 38*38
    
    # -- output 38*38  
    ## Layer 150 [yolo]
    yolo_150 = x   
   
# ---------------------------------- end head output 38*38 ---------------------------------------
    
    # ---------------------------------- begin head output 19*19 ---------------------------------------
    ## Layer 151 [route] layers = -4
    x = layer_147
        
    ## Layer 152 [convolutional]
    x = _conv_block(x, [{'filter':  512, 'kernel': 3, 'stride': 2, 'bnorm': True, 'activ': 1, 'layer_idx': 152}])
    layer_152 = x  
                        
    ## Layer 153 [route] layers = -1, -37                   
    x = concatenate([layer_152, layer_116],  name='concat_153') 
                        
    # -- begin Convulationnal set for 19*19                    
    ## Layer 154 => 160 [convolutional]
    x = _conv_block(x, [{'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':    1, 'layer_idx': 154},
                        {'filter':  1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':    1, 'layer_idx': 155},
                        {'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':    1, 'layer_idx': 156},
                        {'filter':  1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':    1, 'layer_idx': 157},  
                        {'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':    1, 'layer_idx': 158}, 
    # -- end Convulationnal set for 19*19
                        
    # -- beging last Convulationnal 3*3 and 1*1 for 19*19                   
                        {'filter':  1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':    1, 'layer_idx': 159},
                        {'filter':   255, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':    0, 'layer_idx': 160}])  
    # -- end last Convulationnal 3*3 and 1*1 for 19*19                     
    
    # -- output 19*19                    
    ## Layer 161 [yolo]
    yolo_161 = x
    
    # ---------------------------------- end head output 19*19 ---------------------------------------                    
                        
    model = Model(input_image, [yolo_139, yolo_150, yolo_161], name = 'Yolo_v4')    
    return model
# Out:
# 2022-07-15 11:56:49.739127: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow version: 2.4.1
# Eager execution: True
# Keras version: 2.4.0
# Num Physical GPUs Available:  0
# Num Logical GPUs Available:  0
# 2022-07-15 11:56:50.895295: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-07-15 11:56:50.895633: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-07-15 11:56:50.895642: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-07-15 11:56:50.895657: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (mohamed-Latitude-3500): /proc/driver/nvidia/version does not exist
# 2022-07-15 11:56:50.895959: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-15 11:56:50.896278: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %%
# Define the model
model = make_yolov4_model()

# %%
model.summary()
# Out:
# Model: "Yolo_v4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_0 (InputLayer)            [(None, 608, 608, 3) 0
# __________________________________________________________________________________________________
# convn_0 (Conv2D)                (None, 608, 608, 32) 896         input_0[0][0]
# __________________________________________________________________________________________________
# BN_0 (BatchNormalization)       (None, 608, 608, 32) 128         convn_0[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor (TFOpLambd (None, 608, 608, 32) 0           BN_0[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus (TFOpLambda)   (None, 608, 608, 32) 0           tf.convert_to_tensor[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh (TFOpLambda)       (None, 608, 608, 32) 0           tf.math.softplus[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 608, 608, 32) 0           tf.convert_to_tensor[0][0]
#                                                                  tf.math.tanh[0][0]
# __________________________________________________________________________________________________
# zerop_1 (ZeroPadding2D)         (None, 609, 609, 32) 0           tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# convn_1 (Conv2D)                (None, 304, 304, 64) 18496       zerop_1[0][0]
# __________________________________________________________________________________________________
# BN_1 (BatchNormalization)       (None, 304, 304, 64) 256         convn_1[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_1 (TFOpLam (None, 304, 304, 64) 0           BN_1[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_1 (TFOpLambda) (None, 304, 304, 64) 0           tf.convert_to_tensor_1[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_1 (TFOpLambda)     (None, 304, 304, 64) 0           tf.math.softplus_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 304, 304, 64) 0           tf.convert_to_tensor_1[0][0]
#                                                                  tf.math.tanh_1[0][0]
# __________________________________________________________________________________________________
# convn_4 (Conv2D)                (None, 304, 304, 64) 4160        tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# BN_4 (BatchNormalization)       (None, 304, 304, 64) 256         convn_4[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_3 (TFOpLam (None, 304, 304, 64) 0           BN_4[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_3 (TFOpLambda) (None, 304, 304, 64) 0           tf.convert_to_tensor_3[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_3 (TFOpLambda)     (None, 304, 304, 64) 0           tf.math.softplus_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 304, 304, 64) 0           tf.convert_to_tensor_3[0][0]
#                                                                  tf.math.tanh_3[0][0]
# __________________________________________________________________________________________________
# convn_5 (Conv2D)                (None, 304, 304, 32) 2080        tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# BN_5 (BatchNormalization)       (None, 304, 304, 32) 128         convn_5[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_4 (TFOpLam (None, 304, 304, 32) 0           BN_5[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_4 (TFOpLambda) (None, 304, 304, 32) 0           tf.convert_to_tensor_4[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_4 (TFOpLambda)     (None, 304, 304, 32) 0           tf.math.softplus_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 304, 304, 32) 0           tf.convert_to_tensor_4[0][0]
#                                                                  tf.math.tanh_4[0][0]
# __________________________________________________________________________________________________
# convn_6 (Conv2D)                (None, 304, 304, 64) 18496       tf.math.multiply_4[0][0]
# __________________________________________________________________________________________________
# BN_6 (BatchNormalization)       (None, 304, 304, 64) 256         convn_6[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_5 (TFOpLam (None, 304, 304, 64) 0           BN_6[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_5 (TFOpLambda) (None, 304, 304, 64) 0           tf.convert_to_tensor_5[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_5 (TFOpLambda)     (None, 304, 304, 64) 0           tf.math.softplus_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 304, 304, 64) 0           tf.convert_to_tensor_5[0][0]
#                                                                  tf.math.tanh_5[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 304, 304, 64) 0           tf.math.multiply_3[0][0]
#                                                                  tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# convn_8 (Conv2D)                (None, 304, 304, 64) 4160        add_7[0][0]
# __________________________________________________________________________________________________
# convn_2 (Conv2D)                (None, 304, 304, 64) 4160        tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# BN_8 (BatchNormalization)       (None, 304, 304, 64) 256         convn_8[0][0]
# __________________________________________________________________________________________________
# BN_2 (BatchNormalization)       (None, 304, 304, 64) 256         convn_2[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_6 (TFOpLam (None, 304, 304, 64) 0           BN_8[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_2 (TFOpLam (None, 304, 304, 64) 0           BN_2[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_6 (TFOpLambda) (None, 304, 304, 64) 0           tf.convert_to_tensor_6[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_2 (TFOpLambda) (None, 304, 304, 64) 0           tf.convert_to_tensor_2[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_6 (TFOpLambda)     (None, 304, 304, 64) 0           tf.math.softplus_6[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_2 (TFOpLambda)     (None, 304, 304, 64) 0           tf.math.softplus_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_6 (TFOpLambda) (None, 304, 304, 64) 0           tf.convert_to_tensor_6[0][0]
#                                                                  tf.math.tanh_6[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 304, 304, 64) 0           tf.convert_to_tensor_2[0][0]
#                                                                  tf.math.tanh_2[0][0]
# __________________________________________________________________________________________________
# concat_9 (Concatenate)          (None, 304, 304, 128 0           tf.math.multiply_6[0][0]
#                                                                  tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# convn_10 (Conv2D)               (None, 304, 304, 64) 8256        concat_9[0][0]
# __________________________________________________________________________________________________
# BN_10 (BatchNormalization)      (None, 304, 304, 64) 256         convn_10[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_7 (TFOpLam (None, 304, 304, 64) 0           BN_10[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_7 (TFOpLambda) (None, 304, 304, 64) 0           tf.convert_to_tensor_7[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_7 (TFOpLambda)     (None, 304, 304, 64) 0           tf.math.softplus_7[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_7 (TFOpLambda) (None, 304, 304, 64) 0           tf.convert_to_tensor_7[0][0]
#                                                                  tf.math.tanh_7[0][0]
# __________________________________________________________________________________________________
# zerop_11 (ZeroPadding2D)        (None, 305, 305, 64) 0           tf.math.multiply_7[0][0]
# __________________________________________________________________________________________________
# convn_11 (Conv2D)               (None, 152, 152, 128 73856       zerop_11[0][0]
# __________________________________________________________________________________________________
# BN_11 (BatchNormalization)      (None, 152, 152, 128 512         convn_11[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_8 (TFOpLam (None, 152, 152, 128 0           BN_11[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_8 (TFOpLambda) (None, 152, 152, 128 0           tf.convert_to_tensor_8[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_8 (TFOpLambda)     (None, 152, 152, 128 0           tf.math.softplus_8[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_8 (TFOpLambda) (None, 152, 152, 128 0           tf.convert_to_tensor_8[0][0]
#                                                                  tf.math.tanh_8[0][0]
# __________________________________________________________________________________________________
# convn_14 (Conv2D)               (None, 152, 152, 64) 8256        tf.math.multiply_8[0][0]
# __________________________________________________________________________________________________
# BN_14 (BatchNormalization)      (None, 152, 152, 64) 256         convn_14[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_10 (TFOpLa (None, 152, 152, 64) 0           BN_14[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_10 (TFOpLambda (None, 152, 152, 64) 0           tf.convert_to_tensor_10[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_10 (TFOpLambda)    (None, 152, 152, 64) 0           tf.math.softplus_10[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_10 (TFOpLambda (None, 152, 152, 64) 0           tf.convert_to_tensor_10[0][0]
#                                                                  tf.math.tanh_10[0][0]
# __________________________________________________________________________________________________
# convn_15 (Conv2D)               (None, 152, 152, 64) 4160        tf.math.multiply_10[0][0]
# __________________________________________________________________________________________________
# BN_15 (BatchNormalization)      (None, 152, 152, 64) 256         convn_15[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_11 (TFOpLa (None, 152, 152, 64) 0           BN_15[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_11 (TFOpLambda (None, 152, 152, 64) 0           tf.convert_to_tensor_11[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_11 (TFOpLambda)    (None, 152, 152, 64) 0           tf.math.softplus_11[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_11 (TFOpLambda (None, 152, 152, 64) 0           tf.convert_to_tensor_11[0][0]
#                                                                  tf.math.tanh_11[0][0]
# __________________________________________________________________________________________________
# convn_16 (Conv2D)               (None, 152, 152, 64) 36928       tf.math.multiply_11[0][0]
# __________________________________________________________________________________________________
# BN_16 (BatchNormalization)      (None, 152, 152, 64) 256         convn_16[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_12 (TFOpLa (None, 152, 152, 64) 0           BN_16[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_12 (TFOpLambda (None, 152, 152, 64) 0           tf.convert_to_tensor_12[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_12 (TFOpLambda)    (None, 152, 152, 64) 0           tf.math.softplus_12[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_12 (TFOpLambda (None, 152, 152, 64) 0           tf.convert_to_tensor_12[0][0]
#                                                                  tf.math.tanh_12[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 152, 152, 64) 0           tf.math.multiply_10[0][0]
#                                                                  tf.math.multiply_12[0][0]
# __________________________________________________________________________________________________
# convn_18 (Conv2D)               (None, 152, 152, 64) 4160        add_17[0][0]
# __________________________________________________________________________________________________
# BN_18 (BatchNormalization)      (None, 152, 152, 64) 256         convn_18[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_13 (TFOpLa (None, 152, 152, 64) 0           BN_18[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_13 (TFOpLambda (None, 152, 152, 64) 0           tf.convert_to_tensor_13[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_13 (TFOpLambda)    (None, 152, 152, 64) 0           tf.math.softplus_13[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_13 (TFOpLambda (None, 152, 152, 64) 0           tf.convert_to_tensor_13[0][0]
#                                                                  tf.math.tanh_13[0][0]
# __________________________________________________________________________________________________
# convn_19 (Conv2D)               (None, 152, 152, 64) 36928       tf.math.multiply_13[0][0]
# __________________________________________________________________________________________________
# BN_19 (BatchNormalization)      (None, 152, 152, 64) 256         convn_19[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_14 (TFOpLa (None, 152, 152, 64) 0           BN_19[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_14 (TFOpLambda (None, 152, 152, 64) 0           tf.convert_to_tensor_14[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_14 (TFOpLambda)    (None, 152, 152, 64) 0           tf.math.softplus_14[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_14 (TFOpLambda (None, 152, 152, 64) 0           tf.convert_to_tensor_14[0][0]
#                                                                  tf.math.tanh_14[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 152, 152, 64) 0           add_17[0][0]
#                                                                  tf.math.multiply_14[0][0]
# __________________________________________________________________________________________________
# convn_21 (Conv2D)               (None, 152, 152, 64) 4160        add_20[0][0]
# __________________________________________________________________________________________________
# convn_12 (Conv2D)               (None, 152, 152, 64) 8256        tf.math.multiply_8[0][0]
# __________________________________________________________________________________________________
# BN_21 (BatchNormalization)      (None, 152, 152, 64) 256         convn_21[0][0]
# __________________________________________________________________________________________________
# BN_12 (BatchNormalization)      (None, 152, 152, 64) 256         convn_12[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_15 (TFOpLa (None, 152, 152, 64) 0           BN_21[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_9 (TFOpLam (None, 152, 152, 64) 0           BN_12[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_15 (TFOpLambda (None, 152, 152, 64) 0           tf.convert_to_tensor_15[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_9 (TFOpLambda) (None, 152, 152, 64) 0           tf.convert_to_tensor_9[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_15 (TFOpLambda)    (None, 152, 152, 64) 0           tf.math.softplus_15[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_9 (TFOpLambda)     (None, 152, 152, 64) 0           tf.math.softplus_9[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_15 (TFOpLambda (None, 152, 152, 64) 0           tf.convert_to_tensor_15[0][0]
#                                                                  tf.math.tanh_15[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_9 (TFOpLambda) (None, 152, 152, 64) 0           tf.convert_to_tensor_9[0][0]
#                                                                  tf.math.tanh_9[0][0]
# __________________________________________________________________________________________________
# concat_22 (Concatenate)         (None, 152, 152, 128 0           tf.math.multiply_15[0][0]
#                                                                  tf.math.multiply_9[0][0]
# __________________________________________________________________________________________________
# convn_23 (Conv2D)               (None, 152, 152, 128 16512       concat_22[0][0]
# __________________________________________________________________________________________________
# BN_23 (BatchNormalization)      (None, 152, 152, 128 512         convn_23[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_16 (TFOpLa (None, 152, 152, 128 0           BN_23[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_16 (TFOpLambda (None, 152, 152, 128 0           tf.convert_to_tensor_16[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_16 (TFOpLambda)    (None, 152, 152, 128 0           tf.math.softplus_16[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_16 (TFOpLambda (None, 152, 152, 128 0           tf.convert_to_tensor_16[0][0]
#                                                                  tf.math.tanh_16[0][0]
# __________________________________________________________________________________________________
# zerop_24 (ZeroPadding2D)        (None, 153, 153, 128 0           tf.math.multiply_16[0][0]
# __________________________________________________________________________________________________
# convn_24 (Conv2D)               (None, 76, 76, 256)  295168      zerop_24[0][0]
# __________________________________________________________________________________________________
# BN_24 (BatchNormalization)      (None, 76, 76, 256)  1024        convn_24[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_17 (TFOpLa (None, 76, 76, 256)  0           BN_24[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_17 (TFOpLambda (None, 76, 76, 256)  0           tf.convert_to_tensor_17[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_17 (TFOpLambda)    (None, 76, 76, 256)  0           tf.math.softplus_17[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_17 (TFOpLambda (None, 76, 76, 256)  0           tf.convert_to_tensor_17[0][0]
#                                                                  tf.math.tanh_17[0][0]
# __________________________________________________________________________________________________
# convn_27 (Conv2D)               (None, 76, 76, 128)  32896       tf.math.multiply_17[0][0]
# __________________________________________________________________________________________________
# BN_27 (BatchNormalization)      (None, 76, 76, 128)  512         convn_27[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_19 (TFOpLa (None, 76, 76, 128)  0           BN_27[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_19 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_19[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_19 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_19[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_19 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_19[0][0]
#                                                                  tf.math.tanh_19[0][0]
# __________________________________________________________________________________________________
# convn_28 (Conv2D)               (None, 76, 76, 128)  16512       tf.math.multiply_19[0][0]
# __________________________________________________________________________________________________
# BN_28 (BatchNormalization)      (None, 76, 76, 128)  512         convn_28[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_20 (TFOpLa (None, 76, 76, 128)  0           BN_28[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_20 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_20[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_20 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_20[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_20 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_20[0][0]
#                                                                  tf.math.tanh_20[0][0]
# __________________________________________________________________________________________________
# convn_29 (Conv2D)               (None, 76, 76, 128)  147584      tf.math.multiply_20[0][0]
# __________________________________________________________________________________________________
# BN_29 (BatchNormalization)      (None, 76, 76, 128)  512         convn_29[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_21 (TFOpLa (None, 76, 76, 128)  0           BN_29[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_21 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_21[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_21 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_21[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_21 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_21[0][0]
#                                                                  tf.math.tanh_21[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 76, 76, 128)  0           tf.math.multiply_19[0][0]
#                                                                  tf.math.multiply_21[0][0]
# __________________________________________________________________________________________________
# convn_31 (Conv2D)               (None, 76, 76, 128)  16512       add_30[0][0]
# __________________________________________________________________________________________________
# BN_31 (BatchNormalization)      (None, 76, 76, 128)  512         convn_31[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_22 (TFOpLa (None, 76, 76, 128)  0           BN_31[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_22 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_22[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_22 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_22[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_22 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_22[0][0]
#                                                                  tf.math.tanh_22[0][0]
# __________________________________________________________________________________________________
# convn_32 (Conv2D)               (None, 76, 76, 128)  147584      tf.math.multiply_22[0][0]
# __________________________________________________________________________________________________
# BN_32 (BatchNormalization)      (None, 76, 76, 128)  512         convn_32[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_23 (TFOpLa (None, 76, 76, 128)  0           BN_32[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_23 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_23[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_23 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_23[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_23 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_23[0][0]
#                                                                  tf.math.tanh_23[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 76, 76, 128)  0           add_30[0][0]
#                                                                  tf.math.multiply_23[0][0]
# __________________________________________________________________________________________________
# convn_34 (Conv2D)               (None, 76, 76, 128)  16512       add_33[0][0]
# __________________________________________________________________________________________________
# BN_34 (BatchNormalization)      (None, 76, 76, 128)  512         convn_34[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_24 (TFOpLa (None, 76, 76, 128)  0           BN_34[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_24 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_24[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_24 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_24[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_24 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_24[0][0]
#                                                                  tf.math.tanh_24[0][0]
# __________________________________________________________________________________________________
# convn_35 (Conv2D)               (None, 76, 76, 128)  147584      tf.math.multiply_24[0][0]
# __________________________________________________________________________________________________
# BN_35 (BatchNormalization)      (None, 76, 76, 128)  512         convn_35[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_25 (TFOpLa (None, 76, 76, 128)  0           BN_35[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_25 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_25[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_25 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_25[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_25 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_25[0][0]
#                                                                  tf.math.tanh_25[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 76, 76, 128)  0           add_33[0][0]
#                                                                  tf.math.multiply_25[0][0]
# __________________________________________________________________________________________________
# convn_37 (Conv2D)               (None, 76, 76, 128)  16512       add_36[0][0]
# __________________________________________________________________________________________________
# BN_37 (BatchNormalization)      (None, 76, 76, 128)  512         convn_37[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_26 (TFOpLa (None, 76, 76, 128)  0           BN_37[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_26 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_26[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_26 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_26[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_26 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_26[0][0]
#                                                                  tf.math.tanh_26[0][0]
# __________________________________________________________________________________________________
# convn_38 (Conv2D)               (None, 76, 76, 128)  147584      tf.math.multiply_26[0][0]
# __________________________________________________________________________________________________
# BN_38 (BatchNormalization)      (None, 76, 76, 128)  512         convn_38[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_27 (TFOpLa (None, 76, 76, 128)  0           BN_38[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_27 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_27[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_27 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_27[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_27 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_27[0][0]
#                                                                  tf.math.tanh_27[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 76, 76, 128)  0           add_36[0][0]
#                                                                  tf.math.multiply_27[0][0]
# __________________________________________________________________________________________________
# convn_40 (Conv2D)               (None, 76, 76, 128)  16512       add_39[0][0]
# __________________________________________________________________________________________________
# BN_40 (BatchNormalization)      (None, 76, 76, 128)  512         convn_40[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_28 (TFOpLa (None, 76, 76, 128)  0           BN_40[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_28 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_28[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_28 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_28[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_28 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_28[0][0]
#                                                                  tf.math.tanh_28[0][0]
# __________________________________________________________________________________________________
# convn_41 (Conv2D)               (None, 76, 76, 128)  147584      tf.math.multiply_28[0][0]
# __________________________________________________________________________________________________
# BN_41 (BatchNormalization)      (None, 76, 76, 128)  512         convn_41[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_29 (TFOpLa (None, 76, 76, 128)  0           BN_41[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_29 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_29[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_29 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_29[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_29 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_29[0][0]
#                                                                  tf.math.tanh_29[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 76, 76, 128)  0           add_39[0][0]
#                                                                  tf.math.multiply_29[0][0]
# __________________________________________________________________________________________________
# convn_43 (Conv2D)               (None, 76, 76, 128)  16512       add_42[0][0]
# __________________________________________________________________________________________________
# BN_43 (BatchNormalization)      (None, 76, 76, 128)  512         convn_43[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_30 (TFOpLa (None, 76, 76, 128)  0           BN_43[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_30 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_30[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_30 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_30[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_30 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_30[0][0]
#                                                                  tf.math.tanh_30[0][0]
# __________________________________________________________________________________________________
# convn_44 (Conv2D)               (None, 76, 76, 128)  147584      tf.math.multiply_30[0][0]
# __________________________________________________________________________________________________
# BN_44 (BatchNormalization)      (None, 76, 76, 128)  512         convn_44[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_31 (TFOpLa (None, 76, 76, 128)  0           BN_44[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_31 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_31[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_31 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_31[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_31 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_31[0][0]
#                                                                  tf.math.tanh_31[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 76, 76, 128)  0           add_42[0][0]
#                                                                  tf.math.multiply_31[0][0]
# __________________________________________________________________________________________________
# convn_46 (Conv2D)               (None, 76, 76, 128)  16512       add_45[0][0]
# __________________________________________________________________________________________________
# BN_46 (BatchNormalization)      (None, 76, 76, 128)  512         convn_46[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_32 (TFOpLa (None, 76, 76, 128)  0           BN_46[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_32 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_32[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_32 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_32[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_32 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_32[0][0]
#                                                                  tf.math.tanh_32[0][0]
# __________________________________________________________________________________________________
# convn_47 (Conv2D)               (None, 76, 76, 128)  147584      tf.math.multiply_32[0][0]
# __________________________________________________________________________________________________
# BN_47 (BatchNormalization)      (None, 76, 76, 128)  512         convn_47[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_33 (TFOpLa (None, 76, 76, 128)  0           BN_47[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_33 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_33[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh_33 (TFOpLambda)    (None, 76, 76, 128)  0           tf.math.softplus_33[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_33 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_33[0][0]
#                                                                  tf.math.tanh_33[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 76, 76, 128)  0           add_45[0][0]
#                                                                  tf.math.multiply_33[0][0]
# __________________________________________________________________________________________________
# convn_49 (Conv2D)               (None, 76, 76, 128)  16512       add_48[0][0]
# __________________________________________________________________________________________________
# BN_49 (BatchNormalization)      (None, 76, 76, 128)  512         convn_49[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_34 (TFOpLa (None, 76, 76, 128)  0           BN_49[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_34 (TFOpLambda (None, 76, 76, 128)  0           tf.convert_to_tensor_34[0][0]
# __________________________________________________________________________________________________
# ...
# convn_127 (Conv2D)              (None, 38, 38, 128)  32896       leaky_126[0][0]
# __________________________________________________________________________________________________
# convn_130 (Conv2D)              (None, 76, 76, 128)  32896       tf.math.multiply_37[0][0]
# __________________________________________________________________________________________________
# BN_127 (BatchNormalization)     (None, 38, 38, 128)  512         convn_127[0][0]
# __________________________________________________________________________________________________
# BN_130 (BatchNormalization)     (None, 76, 76, 128)  512         convn_130[0][0]
# __________________________________________________________________________________________________
# leaky_127 (LeakyReLU)           (None, 38, 38, 128)  0           BN_127[0][0]
# __________________________________________________________________________________________________
# leaky_130 (LeakyReLU)           (None, 76, 76, 128)  0           BN_130[0][0]
# __________________________________________________________________________________________________
# upsamp_128 (UpSampling2D)       (None, 76, 76, 128)  0           leaky_127[0][0]
# __________________________________________________________________________________________________
# concat_131 (Concatenate)        (None, 76, 76, 256)  0           leaky_130[0][0]
#                                                                  upsamp_128[0][0]
# __________________________________________________________________________________________________
# convn_132 (Conv2D)              (None, 76, 76, 128)  32896       concat_131[0][0]
# __________________________________________________________________________________________________
# BN_132 (BatchNormalization)     (None, 76, 76, 128)  512         convn_132[0][0]
# __________________________________________________________________________________________________
# leaky_132 (LeakyReLU)           (None, 76, 76, 128)  0           BN_132[0][0]
# __________________________________________________________________________________________________
# convn_133 (Conv2D)              (None, 76, 76, 256)  295168      leaky_132[0][0]
# __________________________________________________________________________________________________
# BN_133 (BatchNormalization)     (None, 76, 76, 256)  1024        convn_133[0][0]
# __________________________________________________________________________________________________
# leaky_133 (LeakyReLU)           (None, 76, 76, 256)  0           BN_133[0][0]
# __________________________________________________________________________________________________
# convn_134 (Conv2D)              (None, 76, 76, 128)  32896       leaky_133[0][0]
# __________________________________________________________________________________________________
# BN_134 (BatchNormalization)     (None, 76, 76, 128)  512         convn_134[0][0]
# __________________________________________________________________________________________________
# leaky_134 (LeakyReLU)           (None, 76, 76, 128)  0           BN_134[0][0]
# __________________________________________________________________________________________________
# convn_135 (Conv2D)              (None, 76, 76, 256)  295168      leaky_134[0][0]
# __________________________________________________________________________________________________
# BN_135 (BatchNormalization)     (None, 76, 76, 256)  1024        convn_135[0][0]
# __________________________________________________________________________________________________
# leaky_135 (LeakyReLU)           (None, 76, 76, 256)  0           BN_135[0][0]
# __________________________________________________________________________________________________
# convn_136 (Conv2D)              (None, 76, 76, 128)  32896       leaky_135[0][0]
# __________________________________________________________________________________________________
# BN_136 (BatchNormalization)     (None, 76, 76, 128)  512         convn_136[0][0]
# __________________________________________________________________________________________________
# leaky_136 (LeakyReLU)           (None, 76, 76, 128)  0           BN_136[0][0]
# __________________________________________________________________________________________________
# zerop_141 (ZeroPadding2D)       (None, 77, 77, 128)  0           leaky_136[0][0]
# __________________________________________________________________________________________________
# convn_141 (Conv2D)              (None, 38, 38, 256)  295168      zerop_141[0][0]
# __________________________________________________________________________________________________
# BN_141 (BatchNormalization)     (None, 38, 38, 256)  1024        convn_141[0][0]
# __________________________________________________________________________________________________
# leaky_141 (LeakyReLU)           (None, 38, 38, 256)  0           BN_141[0][0]
# __________________________________________________________________________________________________
# concat_142 (Concatenate)        (None, 38, 38, 512)  0           leaky_141[0][0]
#                                                                  leaky_126[0][0]
# __________________________________________________________________________________________________
# convn_143 (Conv2D)              (None, 38, 38, 256)  131328      concat_142[0][0]
# __________________________________________________________________________________________________
# BN_143 (BatchNormalization)     (None, 38, 38, 256)  1024        convn_143[0][0]
# __________________________________________________________________________________________________
# leaky_143 (LeakyReLU)           (None, 38, 38, 256)  0           BN_143[0][0]
# __________________________________________________________________________________________________
# convn_144 (Conv2D)              (None, 38, 38, 512)  1180160     leaky_143[0][0]
# __________________________________________________________________________________________________
# BN_144 (BatchNormalization)     (None, 38, 38, 512)  2048        convn_144[0][0]
# __________________________________________________________________________________________________
# leaky_144 (LeakyReLU)           (None, 38, 38, 512)  0           BN_144[0][0]
# __________________________________________________________________________________________________
# convn_145 (Conv2D)              (None, 38, 38, 256)  131328      leaky_144[0][0]
# __________________________________________________________________________________________________
# BN_145 (BatchNormalization)     (None, 38, 38, 256)  1024        convn_145[0][0]
# __________________________________________________________________________________________________
# leaky_145 (LeakyReLU)           (None, 38, 38, 256)  0           BN_145[0][0]
# __________________________________________________________________________________________________
# convn_146 (Conv2D)              (None, 38, 38, 512)  1180160     leaky_145[0][0]
# __________________________________________________________________________________________________
# BN_146 (BatchNormalization)     (None, 38, 38, 512)  2048        convn_146[0][0]
# __________________________________________________________________________________________________
# leaky_146 (LeakyReLU)           (None, 38, 38, 512)  0           BN_146[0][0]
# __________________________________________________________________________________________________
# convn_147 (Conv2D)              (None, 38, 38, 256)  131328      leaky_146[0][0]
# __________________________________________________________________________________________________
# BN_147 (BatchNormalization)     (None, 38, 38, 256)  1024        convn_147[0][0]
# __________________________________________________________________________________________________
# leaky_147 (LeakyReLU)           (None, 38, 38, 256)  0           BN_147[0][0]
# __________________________________________________________________________________________________
# zerop_152 (ZeroPadding2D)       (None, 39, 39, 256)  0           leaky_147[0][0]
# __________________________________________________________________________________________________
# convn_152 (Conv2D)              (None, 19, 19, 512)  1180160     zerop_152[0][0]
# __________________________________________________________________________________________________
# BN_152 (BatchNormalization)     (None, 19, 19, 512)  2048        convn_152[0][0]
# __________________________________________________________________________________________________
# leaky_152 (LeakyReLU)           (None, 19, 19, 512)  0           BN_152[0][0]
# __________________________________________________________________________________________________
# concat_153 (Concatenate)        (None, 19, 19, 1024) 0           leaky_152[0][0]
#                                                                  leaky_116[0][0]
# __________________________________________________________________________________________________
# convn_154 (Conv2D)              (None, 19, 19, 512)  524800      concat_153[0][0]
# __________________________________________________________________________________________________
# BN_154 (BatchNormalization)     (None, 19, 19, 512)  2048        convn_154[0][0]
# __________________________________________________________________________________________________
# leaky_154 (LeakyReLU)           (None, 19, 19, 512)  0           BN_154[0][0]
# __________________________________________________________________________________________________
# convn_155 (Conv2D)              (None, 19, 19, 1024) 4719616     leaky_154[0][0]
# __________________________________________________________________________________________________
# BN_155 (BatchNormalization)     (None, 19, 19, 1024) 4096        convn_155[0][0]
# __________________________________________________________________________________________________
# leaky_155 (LeakyReLU)           (None, 19, 19, 1024) 0           BN_155[0][0]
# __________________________________________________________________________________________________
# convn_156 (Conv2D)              (None, 19, 19, 512)  524800      leaky_155[0][0]
# __________________________________________________________________________________________________
# BN_156 (BatchNormalization)     (None, 19, 19, 512)  2048        convn_156[0][0]
# __________________________________________________________________________________________________
# leaky_156 (LeakyReLU)           (None, 19, 19, 512)  0           BN_156[0][0]
# __________________________________________________________________________________________________
# convn_157 (Conv2D)              (None, 19, 19, 1024) 4719616     leaky_156[0][0]
# __________________________________________________________________________________________________
# BN_157 (BatchNormalization)     (None, 19, 19, 1024) 4096        convn_157[0][0]
# __________________________________________________________________________________________________
# leaky_157 (LeakyReLU)           (None, 19, 19, 1024) 0           BN_157[0][0]
# __________________________________________________________________________________________________
# convn_158 (Conv2D)              (None, 19, 19, 512)  524800      leaky_157[0][0]
# __________________________________________________________________________________________________
# BN_158 (BatchNormalization)     (None, 19, 19, 512)  2048        convn_158[0][0]
# __________________________________________________________________________________________________
# leaky_158 (LeakyReLU)           (None, 19, 19, 512)  0           BN_158[0][0]
# __________________________________________________________________________________________________
# convn_137 (Conv2D)              (None, 76, 76, 256)  295168      leaky_136[0][0]
# __________________________________________________________________________________________________
# convn_148 (Conv2D)              (None, 38, 38, 512)  1180160     leaky_147[0][0]
# __________________________________________________________________________________________________
# convn_159 (Conv2D)              (None, 19, 19, 1024) 4719616     leaky_158[0][0]
# __________________________________________________________________________________________________
# BN_137 (BatchNormalization)     (None, 76, 76, 256)  1024        convn_137[0][0]
# __________________________________________________________________________________________________
# BN_148 (BatchNormalization)     (None, 38, 38, 512)  2048        convn_148[0][0]
# __________________________________________________________________________________________________
# BN_159 (BatchNormalization)     (None, 19, 19, 1024) 4096        convn_159[0][0]
# __________________________________________________________________________________________________
# leaky_137 (LeakyReLU)           (None, 76, 76, 256)  0           BN_137[0][0]
# __________________________________________________________________________________________________
# leaky_148 (LeakyReLU)           (None, 38, 38, 512)  0           BN_148[0][0]
# __________________________________________________________________________________________________
# leaky_159 (LeakyReLU)           (None, 19, 19, 1024) 0           BN_159[0][0]
# __________________________________________________________________________________________________
# convn_138 (Conv2D)              (None, 76, 76, 255)  65535       leaky_137[0][0]
# __________________________________________________________________________________________________
# convn_149 (Conv2D)              (None, 38, 38, 255)  130815      leaky_148[0][0]
# __________________________________________________________________________________________________
# convn_160 (Conv2D)              (None, 19, 19, 255)  261375      leaky_159[0][0]
# __________________________________________________________________________________________________
# BN_138 (BatchNormalization)     (None, 76, 76, 255)  1020        convn_138[0][0]
# __________________________________________________________________________________________________
# BN_149 (BatchNormalization)     (None, 38, 38, 255)  1020        convn_149[0][0]
# __________________________________________________________________________________________________
# BN_160 (BatchNormalization)     (None, 19, 19, 255)  1020        convn_160[0][0]
# ==================================================================================================
# Total params: 64,465,617
# Trainable params: 64,397,783
# Non-trainable params: 67,834
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model( model, show_shapes=True)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
from keras.models import Model
import struct

class WeightReader:
    def __init__(self, weight_file):
        with open(weight_file, 'rb') as w_f:
            major,    = struct.unpack('i', w_f.read(4))
            minor,    = struct.unpack('i', w_f.read(4))
            revision, = struct.unpack('i', w_f.read(4))

            if (major*10 + minor) >= 2 and major < 1000 and minor < 1000:
                print("reading 64 bytes")
                w_f.read(8)
            else:
                print("reading 32 bytes")
                w_f.read(4)

            transpose = (major > 1000) or (minor > 1000)
            
            binary = w_f.read()

        self.offset = 0
        self.all_weights = np.frombuffer(binary, dtype='float32')
        
    def read_bytes(self, size):
        self.offset = self.offset + size
        return self.all_weights[self.offset-size:self.offset]

    def load_weights(self, model):
        count = 0
        ncount = 0
        for i in range(161):
            try:

                conv_layer = model.get_layer('convn_' + str(i))
                filter = conv_layer.kernel.shape[-1]
                nweights = np.prod(conv_layer.kernel.shape) # kernel*kernel*c*filter
                
                print("loading weights of convolution #" + str(i)+ "- nb parameters: "+str(nweights+filter))             
                
                if i  in [138, 149, 160]:
                    print("Special processing for layer "+ str(i))
                    bias  = self.read_bytes(filter) # bias
                    weights = self.read_bytes(nweights) # weights
                
                else:                    
                    bias  = self.read_bytes(filter) # bias
                    scale = self.read_bytes(filter) # scale
                    mean  = self.read_bytes(filter) # mean
                    var   = self.read_bytes(filter) # variance
                    weights = self.read_bytes(nweights) # weights
                    
                    bias = bias - scale  * mean / (np.sqrt(var + 0.00001)) #normalize bias

                    weights = np.reshape(weights,(filter,int(nweights/filter)))  #normalize weights
                    A = scale / (np.sqrt(var + 0.00001))
                    A= np.expand_dims(A,axis=0)
                    weights = weights* A.T
                    weights = np.reshape(weights,(nweights))
                

                weights = weights.reshape(list(reversed(conv_layer.get_weights()[0].shape)))                 
                weights = weights.transpose([2,3,1,0])
                
                if len(conv_layer.get_weights()) > 1:
                    a=conv_layer.set_weights([weights, bias])
                else:    
                    a=conv_layer.set_weights([weights])
                
                count = count+1
                ncount = ncount+nweights+filter
             
            except ValueError:
                print("no convolution #" + str(i)) 
        
        print(count, "Conv normalized layers loaded ", ncount, " parameters")
    
    def reset(self):
        self.offset = 0

# %%
# Get and compute the weights
weight_reader = WeightReader('models/yolo/yolov4.weights')
weight_reader.load_weights(model)
# Out:
# reading 64 bytes
# loading weights of convolution #0- nb parameters: 896
# loading weights of convolution #1- nb parameters: 18496
# loading weights of convolution #2- nb parameters: 4160
# no convolution #3
# loading weights of convolution #4- nb parameters: 4160
# loading weights of convolution #5- nb parameters: 2080
# loading weights of convolution #6- nb parameters: 18496
# no convolution #7
# loading weights of convolution #8- nb parameters: 4160
# no convolution #9
# loading weights of convolution #10- nb parameters: 8256
# loading weights of convolution #11- nb parameters: 73856
# loading weights of convolution #12- nb parameters: 8256
# no convolution #13
# loading weights of convolution #14- nb parameters: 8256
# loading weights of convolution #15- nb parameters: 4160
# loading weights of convolution #16- nb parameters: 36928
# no convolution #17
# loading weights of convolution #18- nb parameters: 4160
# loading weights of convolution #19- nb parameters: 36928
# no convolution #20
# loading weights of convolution #21- nb parameters: 4160
# no convolution #22
# loading weights of convolution #23- nb parameters: 16512
# loading weights of convolution #24- nb parameters: 295168
# loading weights of convolution #25- nb parameters: 32896
# no convolution #26
# loading weights of convolution #27- nb parameters: 32896
# loading weights of convolution #28- nb parameters: 16512
# loading weights of convolution #29- nb parameters: 147584
# no convolution #30
# loading weights of convolution #31- nb parameters: 16512
# loading weights of convolution #32- nb parameters: 147584
# no convolution #33
# loading weights of convolution #34- nb parameters: 16512
# loading weights of convolution #35- nb parameters: 147584
# no convolution #36
# loading weights of convolution #37- nb parameters: 16512
# loading weights of convolution #38- nb parameters: 147584
# no convolution #39
# loading weights of convolution #40- nb parameters: 16512
# loading weights of convolution #41- nb parameters: 147584
# no convolution #42
# loading weights of convolution #43- nb parameters: 16512
# loading weights of convolution #44- nb parameters: 147584
# no convolution #45
# loading weights of convolution #46- nb parameters: 16512
# loading weights of convolution #47- nb parameters: 147584
# no convolution #48
# loading weights of convolution #49- nb parameters: 16512
# loading weights of convolution #50- nb parameters: 147584
# no convolution #51
# loading weights of convolution #52- nb parameters: 16512
# no convolution #53
# loading weights of convolution #54- nb parameters: 65792
# loading weights of convolution #55- nb parameters: 1180160
# loading weights of convolution #56- nb parameters: 131328
# no convolution #57
# loading weights of convolution #58- nb parameters: 131328
# loading weights of convolution #59- nb parameters: 65792
# loading weights of convolution #60- nb parameters: 590080
# no convolution #61
# loading weights of convolution #62- nb parameters: 65792
# loading weights of convolution #63- nb parameters: 590080
# no convolution #64
# loading weights of convolution #65- nb parameters: 65792
# loading weights of convolution #66- nb parameters: 590080
# no convolution #67
# loading weights of convolution #68- nb parameters: 65792
# loading weights of convolution #69- nb parameters: 590080
# no convolution #70
# loading weights of convolution #71- nb parameters: 65792
# loading weights of convolution #72- nb parameters: 590080
# no convolution #73
# loading weights of convolution #74- nb parameters: 65792
# loading weights of convolution #75- nb parameters: 590080
# no convolution #76
# loading weights of convolution #77- nb parameters: 65792
# loading weights of convolution #78- nb parameters: 590080
# no convolution #79
# loading weights of convolution #80- nb parameters: 65792
# loading weights of convolution #81- nb parameters: 590080
# no convolution #82
# loading weights of convolution #83- nb parameters: 65792
# no convolution #84
# loading weights of convolution #85- nb parameters: 262656
# loading weights of convolution #86- nb parameters: 4719616
# loading weights of convolution #87- nb parameters: 524800
# no convolution #88
# loading weights of convolution #89- nb parameters: 524800
# loading weights of convolution #90- nb parameters: 262656
# loading weights of convolution #91- nb parameters: 2359808
# no convolution #92
# loading weights of convolution #93- nb parameters: 262656
# loading weights of convolution #94- nb parameters: 2359808
# no convolution #95
# loading weights of convolution #96- nb parameters: 262656
# loading weights of convolution #97- nb parameters: 2359808
# no convolution #98
# loading weights of convolution #99- nb parameters: 262656
# loading weights of convolution #100- nb parameters: 2359808
# no convolution #101
# loading weights of convolution #102- nb parameters: 262656
# no convolution #103
# loading weights of convolution #104- nb parameters: 1049600
# loading weights of convolution #105- nb parameters: 524800
# loading weights of convolution #106- nb parameters: 4719616
# loading weights of convolution #107- nb parameters: 524800
# no convolution #108
# no convolution #109
# no convolution #110
# no convolution #111
# no convolution #112
# no convolution #113
# loading weights of convolution #114- nb parameters: 1049088
# loading weights of convolution #115- nb parameters: 4719616
# loading weights of convolution #116- nb parameters: 524800
# loading weights of convolution #117- nb parameters: 131328
# no convolution #118
# no convolution #119
# loading weights of convolution #120- nb parameters: 131328
# no convolution #121
# loading weights of convolution #122- nb parameters: 131328
# loading weights of convolution #123- nb parameters: 1180160
# loading weights of convolution #124- nb parameters: 131328
# loading weights of convolution #125- nb parameters: 1180160
# loading weights of convolution #126- nb parameters: 131328
# loading weights of convolution #127- nb parameters: 32896
# no convolution #128
# no convolution #129
# loading weights of convolution #130- nb parameters: 32896
# no convolution #131
# loading weights of convolution #132- nb parameters: 32896
# loading weights of convolution #133- nb parameters: 295168
# loading weights of convolution #134- nb parameters: 32896
# loading weights of convolution #135- nb parameters: 295168
# loading weights of convolution #136- nb parameters: 32896
# loading weights of convolution #137- nb parameters: 295168
# loading weights of convolution #138- nb parameters: 65535
# Special processing for layer 138
# no convolution #139
# no convolution #140
# loading weights of convolution #141- nb parameters: 295168
# no convolution #142
# loading weights of convolution #143- nb parameters: 131328
# loading weights of convolution #144- nb parameters: 1180160
# loading weights of convolution #145- nb parameters: 131328
# loading weights of convolution #146- nb parameters: 1180160
# loading weights of convolution #147- nb parameters: 131328
# loading weights of convolution #148- nb parameters: 1180160
# loading weights of convolution #149- nb parameters: 130815
# Special processing for layer 149
# no convolution #150
# no convolution #151
# loading weights of convolution #152- nb parameters: 1180160
# no convolution #153
# loading weights of convolution #154- nb parameters: 524800
# loading weights of convolution #155- nb parameters: 4719616
# loading weights of convolution #156- nb parameters: 524800
# loading weights of convolution #157- nb parameters: 4719616
# loading weights of convolution #158- nb parameters: 524800
# loading weights of convolution #159- nb parameters: 4719616
# loading weights of convolution #160- nb parameters: 261375
# Special processing for layer 160
# 110 Conv normalized layers loaded  64329949  parameters

# %%
# Save the model
! rm models/yolo/yolov4.h5

model.save('models/yolo/yolov4.h5')
! dir models/yolo/*.h5
# Out:
# models/yolo/yolov4.h5

# %%
# Load the model
from keras.models import load_model, Model
yolo_model = load_model("models/yolo/yolov4.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def read_labels(labels_path):
    with open(labels_path) as f:
        labels = f.readlines()
    labels = [c.strip() for c in labels]
    return labels

# %%
# Load the labels
labels = read_labels("models/yolo/coco_classes.txt")
print(labels)
print("nb labels: ",len(labels))
# Out:
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']
# nb labels:  80

# %%
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

# load and prepare an image
def load_image_pixels(filename, shape):
    # load the image to get its shape
    image = load_img(filename)
    width, height = image.size
    # load the image with the required size
    image = load_img(filename, interpolation = 'bilinear', target_size=shape)
    # convert to numpy array
    image = img_to_array(image)
    # scale pixel values to [0, 1]
    image = image.astype('float32')
    image /= 255.0

    # add a dimension so that we have one sample
    image = expand_dims(image, 0)
    
    return image, width, height

# %%
# Pre-process the image
input_w, input_h = 608, 608
photo_filename = 'images/3.jpg'
image, image_w, image_h = load_image_pixels(photo_filename, (input_w, input_h))
print("image initial size: ", image_w, image_h)
print("input image",image.shape)
# Out:
# image initial size:  1280 720
# input image (1, 608, 608, 3)

# %%
# Run the model
yhat = yolo_model.predict(image)

print("output",[a.shape for a in yhat])
# Out:
# output [(1, 76, 76, 255), (1, 38, 38, 255), (1, 19, 19, 255)]

# %%
class BoundBox:
    def __init__(self, xmin, ymin, xmax, ymax, objness = None, classes = None):
        self.xmin = xmin
        self.ymin = ymin
        self.xmax = xmax
        self.ymax = ymax
        self.objness = objness
        self.classes = classes
        self.label = -1
        self.score = -1
 
    def get_label(self):
        if self.label == -1:
            self.label = np.argmax(self.classes)
 
        return self.label
 
    def get_score(self):
        if self.score == -1:
            self.score = self.classes[self.get_label()]
 
        return self.score
 
def _sigmoid(x):
    return 1. / (1. + np.exp(-x))
 
def decode_netout(netout, anchors, obj_thresh, net_h, net_w, nb_box, scales_x_y):
    grid_h, grid_w = netout.shape[:2]  
    netout = netout.reshape((grid_h, grid_w, nb_box, -1))
    nb_class = netout.shape[-1] - 5 # 5 = bx,by,bh,bw,pc

    print("grid_h,grid_w: ",grid_h,grid_w)   
    print("nb class: ",nb_class)   
    
    boxes = []
    netout[..., :2] = _sigmoid(netout[..., :2]) # x, y
    netout[..., :2] = netout[..., :2]*scales_x_y - 0.5*(scales_x_y - 1.0) # scale x, y

    netout[..., 4:] = _sigmoid(netout[..., 4:]) # objectness + classes probabilities

    for i in range(grid_h*grid_w):

        row = i / grid_w
        col = i % grid_w
        
        
        for b in range(nb_box):
            # 4th element is objectness
            objectness = netout[int(row)][int(col)][b][4]

            if(objectness > obj_thresh):
                print("objectness: ",objectness)                
            
                # first 4 elements are x, y, w, and h
                x, y, w, h = netout[int(row)][int(col)][b][:4]
                x = (col + x) / grid_w # center position, unit: image width
                y = (row + y) / grid_h # center position, unit: image height
                w = anchors[2 * b + 0] * np.exp(w) / net_w # unit: image width
                h = anchors[2 * b + 1] * np.exp(h) / net_h # unit: image height            
            
                # last elements are class probabilities
                classes = objectness*netout[int(row)][col][b][5:]
                classes *= classes > obj_thresh
                box = BoundBox(x-w/2, y-h/2, x+w/2, y+h/2, objectness, classes)           
                boxes.append(box)
    return boxes

# %%
# Compute the Yolo layers
obj_thresh = 0.25
anchors = [ [12, 16, 19, 36, 40, 28],[36, 75, 76, 55, 72, 146],[142, 110, 192, 243, 459, 401]]
scales_x_y = [1.2, 1.1, 1.05]
boxes = list()

for i in range(len(anchors)):
    # decode the output of the network
    boxes += decode_netout(yhat[i][0], anchors[i], obj_thresh, input_h, input_w, 3, scales_x_y[i])

print("nb boxes detected; ",len(boxes))
# Out:
# grid_h,grid_w:  76 76
# nb class:  80
# objectness:  0.4732703
# objectness:  0.44099727
# objectness:  0.32971802
# objectness:  0.54038084
# objectness:  0.50902367
# objectness:  0.6325248
# objectness:  0.2923379
# objectness:  0.2904709
# objectness:  0.27239206
# objectness:  0.70321923
# objectness:  0.8777335
# objectness:  0.8465707
# objectness:  0.30681476
# objectness:  0.2647806
# objectness:  0.51768976
# objectness:  0.45398262
# objectness:  0.65101004
# objectness:  0.7007231
# objectness:  0.6422045
# objectness:  0.35053065
# objectness:  0.48313755
# objectness:  0.32775208
# objectness:  0.94621664
# objectness:  0.9278595
# objectness:  0.75643414
# objectness:  0.7396683
# objectness:  0.3013886
# objectness:  0.37305397
# objectness:  0.28342214
# objectness:  0.25097737
# objectness:  0.28581464
# objectness:  0.7351381
# objectness:  0.76510274
# objectness:  0.28823987
# objectness:  0.3368576
# grid_h,grid_w:  38 38
# nb class:  80
# objectness:  0.6975815
# objectness:  0.70409775
# objectness:  0.70986533
# objectness:  0.9097458
# objectness:  0.30098748
# objectness:  0.7293882
# objectness:  0.65752155
# objectness:  0.8312364
# objectness:  0.8322567
# objectness:  0.8292744
# objectness:  0.78591454
# objectness:  0.4531468
# objectness:  0.9486754
# objectness:  0.9125487
# objectness:  0.34026703
# objectness:  0.4554807
# objectness:  0.3587074
# objectness:  0.84384793
# objectness:  0.80374634
# objectness:  0.3864937
# objectness:  0.3621387
# objectness:  0.46942636
# objectness:  0.97232854
# objectness:  0.96607935
# objectness:  0.9728143
# objectness:  0.39788297
# objectness:  0.4136232
# objectness:  0.48248607
# objectness:  0.92907286
# objectness:  0.9127597
# objectness:  0.93749607
# objectness:  0.58350325
# objectness:  0.48476022
# objectness:  0.50998354
# objectness:  0.3255111
# objectness:  0.33360493
# objectness:  0.44655743
# objectness:  0.9802829
# objectness:  0.9789964
# objectness:  0.9852232
# objectness:  0.9539259
# objectness:  0.9423189
# objectness:  0.9554051
# objectness:  0.987241
# objectness:  0.98387194
# objectness:  0.985935
# objectness:  0.29552406
# objectness:  0.25741765
# objectness:  0.25438264
# objectness:  0.25728202
# objectness:  0.4369561
# objectness:  0.4282279
# objectness:  0.40725783
# objectness:  0.32436758
# objectness:  0.34840333
# objectness:  0.3693549
# objectness:  0.33573952
# objectness:  0.34294567
# objectness:  0.34310946
# objectness:  0.34908387
# objectness:  0.55847454
# objectness:  0.8705618
# objectness:  0.5143649
# objectness:  0.9418733
# grid_h,grid_w:  19 19
# nb class:  80
# objectness:  0.7255595
# objectness:  0.85584503
# objectness:  0.92488265
# objectness:  0.7901062
# objectness:  0.95774865
# objectness:  0.9963786
# objectness:  0.2768125
# objectness:  0.40398276
# objectness:  0.6918987
# objectness:  0.50985616
# objectness:  0.6644934
# objectness:  0.6095866
# objectness:  0.9090207
# objectness:  0.90508133
# objectness:  0.91987747
# objectness:  0.91052467
# nb boxes detected;  115

# %%
def correct_yolo_boxes(boxes, image_h, image_w, net_h, net_w):
 new_w, new_h = net_w, net_h
 for i in range(len(boxes)):
        x_offset, x_scale = (net_w - new_w)/2./net_w, float(new_w)/net_w
        y_offset, y_scale = (net_h - new_h)/2./net_h, float(new_h)/net_h
        boxes[i].xmin = int((boxes[i].xmin - x_offset) / x_scale * image_w)
        boxes[i].xmax = int((boxes[i].xmax - x_offset) / x_scale * image_w)
        boxes[i].ymin = int((boxes[i].ymin - y_offset) / y_scale * image_h)
        boxes[i].ymax = int((boxes[i].ymax - y_offset) / y_scale * image_h)

# %%
# Correct the boxes according the inital size of the image
correct_yolo_boxes(boxes, image_h, image_w, input_h, input_w)

# %%
def _interval_overlap(interval_a, interval_b):
    x1, x2 = interval_a
    x3, x4 = interval_b
    if x3 < x1:
        if x4 < x1:
            return 0
        else:
            return min(x2,x4) - x1
    else:
        if x2 < x3:
            return 0
        else:
            return min(x2,x4) - x3
 
def bbox_iou(box1, box2):
    intersect_w = _interval_overlap([box1.xmin, box1.xmax], [box2.xmin, box2.xmax])
    intersect_h = _interval_overlap([box1.ymin, box1.ymax], [box2.ymin, box2.ymax])
    intersect = intersect_w * intersect_h
    w1, h1 = box1.xmax-box1.xmin, box1.ymax-box1.ymin
    w2, h2 = box2.xmax-box2.xmin, box2.ymax-box2.ymin
    union = w1*h1 + w2*h2 - intersect
    return float(intersect) / union

def do_nms(boxes, nms_thresh):
    if len(boxes) > 0:
        nb_class = len(boxes[0].classes)
    else:
        return
    for c in range(nb_class):
        sorted_indices = np.argsort([-box.classes[c] for box in boxes])
        for i in range(len(sorted_indices)):
            index_i = sorted_indices[i]
            if boxes[index_i].classes[c] == 0: continue
            for j in range(i+1, len(sorted_indices)):
                index_j = sorted_indices[j]
                if bbox_iou(boxes[index_i], boxes[index_j]) >= nms_thresh:
                    boxes[index_j].classes[c] = 0

# %%
# Suppress the non Maximal boxes
do_nms(boxes, 0.5)
print("nb boxes remaining; ",len(boxes))
# Out:
# nb boxes remaining;  115

# %%
import colorsys
import random

def generate_colors(class_names):
    hsv_tuples = [(x / len(class_names), 1., 1.) for x in range(len(class_names))]
    colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
    colors = list(map(lambda x: (int(x[0] ), int(x[1] ), int(x[2] )), colors))
    random.seed(10101)  # Fixed seed for consistent colors across runs.
    random.shuffle(colors)  # Shuffle colors to decorrelate adjacent classes.
    random.seed(None)  # Reset seed to default.
    return colors

# get all of the results above a threshold
def get_boxes(boxes, labels, thresh, colors):
    v_boxes, v_labels, v_scores, v_colors = list(), list(), list(), list()
    # enumerate all boxes
    for box in boxes:
        # enumerate all possible labels
        for i in range(len(labels)):

            # check if the threshold for this label is high enough
            if box.classes[i] > thresh:
                v_boxes.append(box)
                v_labels.append(labels[i])
                v_scores.append(box.classes[i]*100)
                v_colors.append(colors[i])
                # don't break, many labels may trigger for one box
    return v_boxes, v_labels, v_scores, v_colors

# %%
# Get the details of the detected objects for a threshold > 0.6
class_threshold = 0.6
colors = generate_colors(labels)
v_boxes, v_labels, v_scores, v_colors = get_boxes(boxes, labels, class_threshold, colors)
print("nb boxes remaining; ",len(v_boxes))
# Out:
# nb boxes remaining;  10

# %%
from matplotlib import pyplot
from matplotlib.patches import Rectangle

# draw all results
def draw_boxes(filename, v_boxes, v_labels, v_scores, v_colors):
    # load the image
    data = pyplot.imread(filename)
    # plot the image
    pyplot.imshow(data)
    # get the context for drawing boxes
    ax = pyplot.gca()
    # plot each box
    for i in range(len(v_boxes)):
        box = v_boxes[i]
        # get coordinates
        y1, x1, y2, x2 = box.ymin, box.xmin, box.ymax, box.xmax
        # calculate width and height of the box
        width, height = x2 - x1, y2 - y1
        # create the shape
        rect = Rectangle((x1, y1), width, height, fill=False, color=v_colors[i])
        # draw the box
        ax.add_patch(rect)
        # draw text and score in top left corner
        label = "%s (%.3f)" % (v_labels[i], v_scores[i])
        pyplot.text(x1, y1, label, color='white')
    # show the plot
    pyplot.show()

# %%
# Draw the result
for i in range(len(v_boxes)):
    print(v_labels[i], v_scores[i],  v_boxes[i].xmin, v_boxes[i].xmax, v_boxes[i].ymin, v_boxes[i].ymax)
# draw what we found
draw_boxes(photo_filename, v_boxes, v_labels, v_scores, v_colors)
# Out:
# backpack 75.46712160110474 380 441 325 393
# person 90.9555196762085 1007 1038 320 388
# person 94.85119581222534 1176 1218 322 401
# handbag 81.47050738334656 212 264 347 432
# person 93.71371269226074 188 269 311 499
# person 98.49675297737122 274 339 314 492
# bicycle 94.09958720207214 569 814 402 616
# person 85.42889356613159 577 648 287 438
# person 99.56620931625366 360 454 302 536
# bicycle 69.1456139087677 506 665 395 566
